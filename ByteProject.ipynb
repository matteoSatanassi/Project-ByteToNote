# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="Qwen/Qwen3.5-0.8B")
# Out:
# Loading weights: 100%|██████████| 320/320 [00:00<00:00, 20321.55it/s]

# %%
pipe('L:1/8 M:4/4 K:Emin |: E2 EF E2 EF | DEFG AFDF | E2 EF E2 B2 |1 efe^d e2 e2 :|2 efe^d e3 B |: e2 ef g2 fe |  defg afdf |1 e2 ef g2 fe | efe^d e3 B :|2 g2 bg f2 af | efe^d e2 e2 ||')
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'continue this : L:1/8 M:4/4 K:Emin |: E2 EF E2 EF | DEFG AFDF | E2 EF E2 B2 |1 efe^d e2 e2 :|2 efe^d e3 B |: e2 ef g2 fe |  defg afdf |1 e2 ef g2 fe | efe^d e3 B :|2 g2 bg f2 af | efe^d e2 e2 |||\n1. 1.1, 1.2, 1.3, 1.4\n2. 2.2, 2.3, 2.4, 2.5\n3. 3.2, 3.3, 3.4\n4. 4.2, 4.3\n5. 5.2, 5.3, 5.4\n6. 6.2, 6.3, 6.4\n7. 7.2, 7.3, 7.4\n8. 8.2, 8.3, 8.4\n9. 9.2, 9.3, 9.4\n10. 10.2, 10.3, 10.4\n11. 11.2, 11.3, 11.4\n12. 12.2, 12.3, 12.4\n13. 13.2, 13.3, 13.4\n14. 14.2, 14'}]

# %%
from datasets import load_dataset

ds = load_dataset("sander-wood/irishman")
# Out:
# Generating train split: 100%|██████████| 214122/214122 [00:00<00:00, 320329.38 examples/s]
# Generating validation split: 100%|██████████| 2162/2162 [00:00<00:00, 338348.76 examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['abc notation', 'control code'],
#         num_rows: 214122
#     })
#     validation: Dataset({
#         features: ['abc notation', 'control code'],
#         num_rows: 2162
#     })
# })

# %%
from music21 import converter

# %%
score = converter.parse("""X: 1
T: The Enchanted Valley
M: 2/4
L: 1/16
B: "O'Neill's 1"
N: "Very slow" "collected by J. O'Neill"
N:
Z: "Transcribed by Norbert Paap, norbertp@bdu.uva.nl"
Z:
K:Gm
G3-A (Bcd=e) | f4 (g2dB) | ({d}c3-B) G2-E2 | F4 (D2=E^F) |
G3-A (Bcd=e) | f4 d2-f2 | (g2a2 b2).g2 | {b}(a2g2 f2).d2 |
(d2{ed}c2) B2B2 | (A2G2 {AG}F2).D2 | (GABc) (d2{ed}c>A) | G2G2 G2z ||
G | B2c2 (dcAB) | G2G2 G3G | B2d2 (gfdc) | d2g2 (g3ga) |
(bagf) (gd)d>c | (B2AG) F-D.D2 | (GABc) d2d2 | (bgfd) cA.F2 |
G2A2 (B2{cB}AG) | A3-G F2-D2 | (GABc) (d2{ed}c>A) | G2G2 G2z2 ||
""", format="abc")

# %%
score.write('midi', fp='enchanted_valley.mid')
# Out:
# ---------------------------------------------------------------------------
# StreamException                           Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 score.write('midi', fp='enchanted_valley.mid')
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/stream/base.py:402, in Stream.write(self, fmt, fp, **keywords)
#     398     def write(self, fmt=None, fp=None, **keywords):
#     399         # ...    --- see base.py calls .write(
#     400         if not self.isSorted and self.autoSort:  # pragma: no cover
#     401             self.sort()
# --> 402         return super().write(fmt=fmt, fp=fp, **keywords)
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/base.py:2921, in Music21Object.write(self, fmt, fp, **keywords)
#    2919     raise Music21ObjectException(f'cannot support output in this format yet: {fmt}')
#    2920 formatWriter = scClass()
# -> 2921 return formatWriter.write(self,
#    2922                           fmt=regularizedConverterFormat,
#    2923                           fp=fp,
#    2924                           subformats=subformats,
#    2925                           **keywords)
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/converter/subConverters.py:1098, in ConverterMidi.write(self, obj, fmt, fp, subformats, addStartDelay, addEndDelay, encoding, **keywords)
#    1095 if fp is None:
#    1096     fp = self.getTemporaryFile()
# -> 1098 mf = midiTranslate.music21ObjectToMidiFile(obj, addStartDelay=addStartDelay,
#    1099                                            addEndDelay=addEndDelay,
#    1100                                            encoding=encoding or self.encoding)
#    1101 mf.open(fp, 'wb')  # write binary
#    1102 mf.write()
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/midi/translate.py:319, in music21ObjectToMidiFile(music21Object, addStartDelay, addEndDelay, encoding)
#     316     if music21Object.atSoundingPitch is False:
#     317         music21Object = music21Object.toSoundingPitch()
# --> 319     return streamToMidiFile(t.cast(stream.Stream, music21Object),
#     320                             addStartDelay=addStartDelay,
#     321                             addEndDelay=addEndDelay,
#     322                             encoding=encoding)
#     323 else:
#     324     m21ObjectCopy = copy.deepcopy(music21Object)
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/midi/translate.py:2828, in streamToMidiFile(inputM21, addStartDelay, addEndDelay, acceptableChannelList, encoding)
#    2798 '''
#    2799 Converts a Stream hierarchy into a :class:`~music21.midi.MidiFile` object.
#    2800
#    (...)   2825 * New in v10.3: addEndDelay keyword.
#    2826 '''
#    2827 s = inputM21
# -> 2828 midiTracks = streamHierarchyToMidiTracks(s,
#    2829                                          addStartDelay=addStartDelay,
#    2830                                          addEndDelay=addEndDelay,
#    2831                                          acceptableChannelList=acceptableChannelList,
#    2832                                          encoding=encoding,
#    2833                                          )
#    2835 # may need to update channel information
#    2837 mf = MidiFile()
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/midi/translate.py:2681, in streamHierarchyToMidiTracks(inputM21, acceptableChannelList, addStartDelay, addEndDelay, encoding)
#    2654 '''
#    2655 Given a Stream, Score, Part, etc., that may have substreams (i.e.,
#    2656 a hierarchy), return a list of :class:`~music21.midi.MidiTrack` objects.
#    (...)   2678 * New in v10.3: addEndDelay keyword.
#    2679 '''
#    2680 # makes a deepcopy
# -> 2681 s = prepareStreamForMidi(inputM21)
#    2682 channelByInstrument, channelsDynamic = channelInstrumentData(s, acceptableChannelList)
#    2684 # return a list of MidiTrack objects
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/midi/translate.py:2297, in prepareStreamForMidi(s)
#    2294 else:
#    2295     s = s.coreCopyAsDerivation('prepareStreamForMidi')
# -> 2297 conductor = conductorStream(s)
#    2299 if s.hasPartLikeStreams():
#    2300     # process Volumes one part at a time
#    2301     # this assumes that dynamics in a part/stream apply to all components
#    2302     # of that part stream
#    2303     # this sets the cachedRealized value for each Volume
#    2304     for p in s.getElementsByClass(stream.Stream):
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/midi/translate.py:2375, in conductorStream(s)
#    2373     # Don't overwrite an event of the same class at this offset
#    2374     if offset_in_s > lastOffset:
# -> 2375         conductorPart.insert(offset_in_s, el)
#    2376     lastOffset = offset_in_s
#    2377 for s_or_inner_stream in s.recurse(streamsOnly=True, includeSelf=True):
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/stream/base.py:2329, in Stream.insert(self, offsetOrItemOrList, itemOrNone, ignoreSort, setActiveSite)
#    2325
#    2326         element = item
#    2327
#    2328         # checks if element is self, among other checks
# -> 2329         self.coreGuardBeforeAddElement(element)
#    2330         # main insert procedure here
#    2331
#    2332         storeSorted = self.coreInsert(offset,
#
# File ~/PycharmProjects/Project-ByteToNote/.venv/lib/python3.14/site-packages/music21/stream/core.py:429, in StreamCore.coreGuardBeforeAddElement(self, element, checkRedundancy)
#     427     for eInStream in search_place:
#     428         if eInStream is element:
# --> 429             raise StreamException(
#     430                 f'the object ({element!r}, id()={id(element)} '
#     431                 f'is already found in this Stream ({self!r}, id()={id(self)})'
#     432             )
#     433 # something was old. delete from _offsetDict
#     434 # environLocal.warn('stale object')
#     435 del self._offsetDict[idElement]  # pragma: no cover
#
# StreamException: the object (<music21.meter.TimeSignature 2/4>, id()=4706669904 is already found in this Stream (<music21.stream.Part 0x118896ad0>, id()=4706626256)
