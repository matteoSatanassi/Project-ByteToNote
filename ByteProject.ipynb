# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="Qwen/Qwen3.8-27B")
messages = [
    {"write a simple python script"},
]
pipe(messages)
# Out:
# Fetching 18 files:   0%|          | 0/18 [00:00<?, ?it/s]
